# %% [markdown]
# # DSCI 552_ HW0
# ### Seongmoon Cho(#1442-9511-30)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 1. IDE

# %% [markdown]
# Using miniconda, I set up the IDE for this homework.

# %% [markdown]
# ## 2. Google Colab

# %% [markdown]
# https://colab.research.google.com/notebooks/intro.ipynb

# %% [markdown]
# ## 3. Pandas

# %% [markdown]
# #### 3(a), 3(b), 3(c)

# %%
# import Salaries.csv as dataframe with the index column of playerID skipping the second row
data = pd.read_csv('Salaries.csv', index_col='playerID', skiprows=[2]) 

# show the first five rows
data.head()
# Out:
#            yearID teamID lgID  salary
# playerID
# barkele01    1985    ATL   NL  870000
# benedbr01    1985    ATL   NL  545000
# campri01     1985    ATL   NL  633333
# ceronri01    1985    ATL   NL  625000
# chambch01    1985    ATL   NL  800000

# %% [markdown]
# #### 3(d)

# %%
# select the id of the players who are registered in ATL and HOU whose salary is higher than one million
greater_than_1_mil = data[((data.teamID=='ATL')|(data.teamID=='HOU'))&(data.salary>=1000000)]
greater_than_1_mil
# Out:
#            yearID teamID lgID   salary
# playerID
# hornebo01    1985    ATL   NL  1500000
# murphda05    1985    ATL   NL  1625000
# suttebr01    1985    ATL   NL  1354167
# ryanno01     1985    HOU   NL  1350000
# hornebo01    1986    ATL   NL  1800000
# ...           ...    ...  ...      ...
# rasmuco01    2015    HOU   AL  8000000
# singljo02    2015    HOU   AL  2000000
# sippto01     2015    HOU   AL  2400000
# thatcjo01    2015    HOU   AL  1000000
# valbulu01    2015    HOU   AL  4200000
#
# [625 rows x 4 columns]

# %% [markdown]
# #### 3(e)

# %%
# calculate the standard deviation, first quartile, median, third quartile, mean, maximum, and minimum of the salary in team ATL
data_ATL = data[(data.teamID=='ATL')]
data_ATL.describe()
# Out:
#             yearID        salary
# count   885.000000  8.850000e+02
# mean   1999.725424  2.208111e+06
# std       8.766470  3.434162e+06
# min    1985.000000  6.000000e+04
# 25%    1992.000000  3.000000e+05
# 50%    1999.000000  6.000000e+05
# 75%    2007.000000  2.400000e+06
# max    2015.000000  1.606180e+07

# %% [markdown]
# #### 3(f)

# %%
# create a Python dictionary object
data = pd.read_csv('Salaries.csv')
result = data.to_dict(orient='records')
# result

# %% [markdown]
# #### 3(g)

# %%
# create a dataframe using pd.DataFrameRead and from the dictionary created in (e)
# and change the header to "a", "b", "c", ...
df=pd.DataFrame(result)
df.columns = ['a', 'b', 'c', 'd', 'e']
df
# Out:
#           a    b   c          d         e
# 0      1985  ATL  NL  barkele01    870000
# 1      1985  ATL  NL  bedrost01    550000
# 2      1985  ATL  NL  benedbr01    545000
# 3      1985  ATL  NL   campri01    633333
# 4      1985  ATL  NL  ceronri01    625000
# ...     ...  ...  ..        ...       ...
# 25570  2015  WAS  NL  treinbl01    512800
# 25571  2015  WAS  NL  ugglada01    507500
# 25572  2015  WAS  NL  werthja01  21000000
# 25573  2015  WAS  NL  zimmejo02  16500000
# 25574  2015  WAS  NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# ## 4. Numpy

# %% [markdown]
# #### 4(a)

# %%
# create a 2-dimensional Python list object, 
a = [[1, 2], [3, 4]]

# then convert it to a Numpy array object
arr = np.array(a)
arr
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# #### 4(b)

# %%
# examine the ndim
arr. ndim ## dimension of array
# Out:
# 2

# %%
# examine the shape
arr.size
# Out:
# 4

# %% [markdown]
# #### 4(c)

# %%
# use flatten()
b=arr.flatten()
b
# Out:
# array([1, 2, 3, 4])

# %%
# use reshape()
c = np.reshape(b, (2,2))
c
# Out:
# array([[1, 2],
#        [3, 4]])

# %% [markdown]
# #### 4(d)

# %%
# slice operations
arr = np.array([[1, 2, 3], [3, 4, 6], [7, 8, 9]])
print(arr[1:])
arr[1:, 0:2]
# Out:
# [[3 4 6]
#  [7 8 9]]
# array([[3, 4],
#        [7, 8]])

# %% [markdown]
# #### 4(e)

# %%
# Calcuations of ndarray objects
np.square(arr)
# Out:
# array([[ 1,  4,  9],
#        [ 9, 16, 36],
#        [49, 64, 81]], dtype=int32)

# %%
np.argmin(arr, axis=1)
# Out:
# array([0, 0, 0], dtype=int64)

# %%
np.argmax(arr)
# Out:
# 8

# %%
np.min(arr)
# Out:
# 1

# %%
np.exp(arr)
# Out:
# array([[2.71828183e+00, 7.38905610e+00, 2.00855369e+01],
#        [2.00855369e+01, 5.45981500e+01, 4.03428793e+02],
#        [1.09663316e+03, 2.98095799e+03, 8.10308393e+03]])

# %% [markdown]
# #### 4(f)

# %%
np.eye(2)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# ## 5. Scikit-Learn

# %% [markdown]
# Scikit-Learn and Scipy Packages
# * Data Preprocessing
# * KNN: KNeighborsClassifier
# * Linear Regression: LinearRegression
# * Logistic Regression: LogisticRegression, LogisticRegressionCV
# * Feature Selection / Model Selection
# * Decision Tree: DecisionTreeClassifier, DecisionTreeRegressor
# * Bootstrap, Ensemble Methods
# * Support Vector Machines: LinearSVC, LinearSVR
# * Multiclass and Multilabel Classification
# * Unsupervised Learning
# * Semi-supervised Learning

# %% [markdown]
# ## 6. Git and GitHub

# %% [markdown]
# 1. In the directory that where this jupyter notebook file locates in, init a Git repository.
# 2. Checkout a new branch called dev and commit the current notebook within this branch.
# 3. Merge the dev branch to the master branch (the default branch).
# 4. Create a temporary repository (just for practicing and you can delete it later) in GitHub.
# 5. Push new changes in the master branch to the remote repository created in step 4.
# 6. Checkout the dev branch again and do some changes to your notebook, and then repeat step 3 and step 5.

# %% [markdown]
# ## 7. Matplotlib

# %% [markdown]
# #### 7(a)

# %%
# create two one dimensional arrays x and y and plot y vs x, add title, xlabel, ylabel, grid
x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Graph')
plt.grid(ls='-.')
plt.show()

# %% [markdown]
# #### 7(b)

# %%
# create multiple arrays and plot them with different styles, add legends, add text/mathematical equations on the plot
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

plt.plot(x, y1, 'ys-')
plt.text(-1.5, -2, r'equation: $Y = X$', fontsize = 10)
plt.xlabel('x')
plt.ylabel('y1')
plt.show()

plt.plot(x, y2, 'go--')
plt.text(-1.5, 5, r'equation: $Y = X^2$', fontsize = 10)
plt.xlabel('x')
plt.ylabel('y2')
plt.show()

plt.plot(x, y3,'bH-.')
plt.text(-1.5, -20, r'equation: $Y = X^3$', fontsize = 10)
plt.xlabel('x')
plt.ylabel('y3')
plt.show()

# %% [markdown]
# #### 7(c)

# %%
# create multiple subplots, play around with the figure size, text font/size
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(7, 14))
fig.suptitle('Subplots')
ax1.plot(x, y1)
ax1.set_title('Y=X')

ax2.plot(x, y2)
ax2.set_title('Y=X^2')

ax3.plot(x, y3)
ax3.set_title('Y=X^3')

plt.show()

# %% [markdown]
# #### 7(d)

# %%
# get familiar with get current axis (gca) handle to do the above tasks
plt.gca().plot([0,1,4])

# %% [markdown]
# #### 7(e)

# %%
# change the limits on x and y axes, use logarithmic axes to plot
x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])

fig, ax = plt.subplots()

ax.plot(x, y)

ax.set_xscale('log')
ax.set_yscale('log')

plt.xlabel('logx')
plt.ylabel('logy')

plt.show()

# %% [markdown]
# ## 8. Seaborn

# %% [markdown]
# #### 8(a)-8(b)

# %%
# use the Salaries.csv file in Pandas section
data = pd.read_csv('Salaries.csv', index_col='playerID')

# create a dataframe
df=pd.DataFrame(data)
df.columns = ['yearID', 'teamID', 'lgID', 'salary']
df.head()
# Out:
#            yearID teamID lgID  salary
# playerID
# barkele01    1985    ATL   NL  870000
# bedrost01    1985    ATL   NL  550000
# benedbr01    1985    ATL   NL  545000
# campri01     1985    ATL   NL  633333
# ceronri01    1985    ATL   NL  625000

# %%
# and try to plot it with seaborn
sns.scatterplot(x="yearID", y="salary", data=df)
# Out:
# <AxesSubplot:xlabel='yearID', ylabel='salary'>

# %% [markdown]
# #### 8(c)

# %%
# perform statistical estimation on the data using seaborn in-built functions
# lmplot
g = sns.lmplot(x="yearID", y="salary", data=df)

# %%
# catplot
g = sns.catplot(x="teamID", y="salary", col='lgID', data=df)

# %%
# relplot
g = sns.relplot(x="yearID", y="salary", hue='teamID', col='lgID', data=df)

# %% [markdown]
# #### 8(d) create axis level functions like boxplot to visualize

# %%
# create axis level functions like boxplot to visualize
df1 = df
df1['salary'] = df['salary'].astype(int)

fig, ax = plt.subplots(figsize=(7,5))
sns.boxplot(x='teamID', y='salary', data=df)
fig.subplots_adjust(top=0.9)

# %% [markdown]
# #### 8(e) visualize the dataset structure using pairplot and jointplot

# %%
# visualize the dataset structure using pairplot and jointplot
# jointplot
sns.jointplot(data=df, x="yearID", y="salary")

# %%
# pairplot
var_set = [
    "yearID",
    "teamID",
    "lgID",
    "playerID",
    "salary"
]

head_set = []
head_set.extend(var_set)
head_set.append("num_feat")

df = pd.read_csv('Salaries.csv', index_col='playerID', header=None, names=head_set)

df['num_feat'] = 100 * np.random.random_sample(df.shape[0])

df_copy = df
cols_with_team_ATL = df_copy.loc[df_copy.teamID=="ATL", ]

# Create the default pairplot
pairplot_fig = sns.pairplot(cols_with_team_ATL, vars=['yearID', 'salary', 'num_feat'])
plt.subplots_adjust(top=0.9)

plt.show()
